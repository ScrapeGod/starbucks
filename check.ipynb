# %%
import requests
from starbucks.menu import get_product_details, get_all_menu
from starbucks.stores import get_stores, get_store_details
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import requests
#       2 from starbucks.menu import get_product_details, get_all_menu
# ----> 3 from starbucks.stores import get_stores, get_store_details
#
# ImportError: cannot import name 'get_store_details' from 'starbucks.stores' (c:\Users\Bikash\OneDrive\Desktop\starbucks\starbucks\stores.py)

# %%
get_product_details('2122638')
get_all_menu()
# Out:
# https://www.starbucks.com/bff/ordering/2122638/packaged
# {'menus': [{'name': 'Drinks',
#    'products': [],
#    'children': [{'name': 'Hot Coffees',
#      'products': [],
#      'children': [{'name': 'Americanos',
#        'products': [{'name': 'Caffè Americano',
#          'formCode': 'Hot',
#          'productNumber': 406,
#          'productType': 'Beverage',
#          'availability': 'Available',
#          'assets': {'masterImage': {}},
#          'sizes': [{'sizeCode': 'Short'},
#           {'sizeCode': 'Tall'},
#           {'sizeCode': 'Grande'},
#           {'sizeCode': 'Venti'}]}],
#        'children': []},
#       {'name': 'Brewed Coffees',
#        'products': [{'name': 'Starbucks® Christmas Blonde Roast Clover Vertica™',
#          'formCode': 'Hot',
#          'productNumber': 2123794,
#          'productType': 'Beverage',
#          'availability': 'Available',
#          'assets': {'masterImage': {}},
#          'sizes': [{'sizeCode': 'Short'},
# ...

# %%
get_stores(place="New York")
# Out:
# [{'distance': 0.0863,
#   'isFavorite': False,
#   'isNearby': True,
#   'isPrevious': False,
#   'recommendationReason': 'NEARBY',
#   'store': {'id': '12020',
#    'closingSoon': False,
#    'storeNumber': '849-2059',
#    'name': 'Park Row at Beekman St',
#    'ownershipTypeCode': 'CO',
#    'phoneNumber': '+1 212-608-8073',
#    'open': False,
#    'isOpen24Hours': False,
#    'openStatusFormatted': 'Opens Monday at 5:00 AM',
#    'hoursStatusFormatted': 'Open today from 5:00 AM - 8:00 PM',
#    'address': {'lines': ['38 Park Row', 'New York, NY 10038'],
#     'singleLine': '38 Park Row, New York',
#     'streetAddressLine1': '38 Park Row',
#     'streetAddressLine2': None,
#     'streetAddressLine3': '#4',
#     'city': 'New York',
#     'countrySubdivisionCode': 'NY',
#     'countryCode': 'US',
#     'postalCode': '10038'},
#    'schedule': [{'dayFormatted': 'Monday',
#      'dayOfWeek': 'MONDAY',
#      'hoursFormatted': '5:00 AM to 8:00 PM',
#      'holidayFormatted': '',
# ...
